# %%
import pandas as pd

# %%
train = pd.read_csv("/Users/irenewalken/Documents/GitHub/Airline-Passenger-Satisfaction-Machine_learning-/Data/train.csv")
test = pd.read_csv("/Users/irenewalken/Documents/GitHub/Airline-Passenger-Satisfaction-Machine_learning-/Data/test.csv")
data = pd.concat([train, test])
data
# Out:
#        Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0               0   70172    Male     Loyal Customer   13  Personal Travel
# 1               1    5047    Male  disloyal Customer   25  Business travel
# 2               2  110028  Female     Loyal Customer   26  Business travel
# 3               3   24026  Female     Loyal Customer   25  Business travel
# 4               4  119299    Male     Loyal Customer   61  Business travel
# ...           ...     ...     ...                ...  ...              ...
# 25971       25971   78463    Male  disloyal Customer   34  Business travel
# 25972       25972   71167    Male     Loyal Customer   23  Business travel
# 25973       25973   37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974   90086    Male     Loyal Customer   14  Business travel
# 25975       25975   34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
data = data.drop(["Unnamed: 0"], axis = 1)
data = data.drop(["id"], axis = 1)

data.to_csv('/Users/irenewalken/Documents/GitHub/Airline-Passenger-Satisfaction-Machine_learning-/Airline-Passenger-Satisfaction-Machine_learning.csv')
data
# Out:
#        Gender      Customer Type  Age   Type of Travel     Class  \
# 0        Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1        Male  disloyal Customer   25  Business travel  Business
# 2      Female     Loyal Customer   26  Business travel  Business
# 3      Female     Loyal Customer   25  Business travel  Business
# 4        Male     Loyal Customer   61  Business travel  Business
# ...       ...                ...  ...              ...       ...
# 25971    Male  disloyal Customer   34  Business travel  Business
# 25972    Male     Loyal Customer   23  Business travel  Business
# 25973  Female     Loyal Customer   17  Personal Travel       Eco
# 25974    Male     Loyal Customer   14  Business travel  Business
# 25975  Female     Loyal Customer   42  Personal Travel       Eco
#
#        Flight Distance  Inflight wifi service  \
# 0                  460                      3
# 1                  235                      3
# ...

# %%
data = data.dropna()

# %%
data = data.drop(["Arrival Delay in Minutes"], axis = 1)
data
# Out:
#        Gender      Customer Type  Age   Type of Travel     Class  \
# 0        Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1        Male  disloyal Customer   25  Business travel  Business
# 2      Female     Loyal Customer   26  Business travel  Business
# 3      Female     Loyal Customer   25  Business travel  Business
# 4        Male     Loyal Customer   61  Business travel  Business
# ...       ...                ...  ...              ...       ...
# 25971    Male  disloyal Customer   34  Business travel  Business
# 25972    Male     Loyal Customer   23  Business travel  Business
# 25973  Female     Loyal Customer   17  Personal Travel       Eco
# 25974    Male     Loyal Customer   14  Business travel  Business
# 25975  Female     Loyal Customer   42  Personal Travel       Eco
#
#        Flight Distance  Inflight wifi service  \
# 0                  460                      3
# 1                  235                      3
# ...

# %%
temp=pd.DataFrame(columns=data.columns.to_list())

result=[]

for col in data.columns:
    result.append(list(data[col]))
    
temp.loc[0] = result
temp
# Out:
#                                               Gender  \
# 0  [Male, Male, Female, Female, Male, Female, Mal...
#
#                                        Customer Type  \
# 0  [Loyal Customer, disloyal Customer, Loyal Cust...
#
#                                                  Age  \
# 0  [13, 25, 26, 25, 61, 26, 47, 52, 41, 20, 24, 1...
#
#                                       Type of Travel  \
# 0  [Personal Travel, Business travel, Business tr...
#
#                                                Class  \
# 0  [Eco Plus, Business, Business, Business, Busin...
#
#                                      Flight Distance  \
# 0  [460, 235, 1142, 562, 214, 1180, 1276, 2035, 8...
#
#                                Inflight wifi service  \
# 0  [3, 3, 2, 2, 3, 3, 2, 4, 1, 3, 4, 2, 1, 4, 3, ...
#
#                    Departure/Arrival time convenient  \
# 0  [4, 2, 2, 5, 3, 4, 4, 3, 2, 3, 5, 4, 4, 2, 2, ...
#
#                               Ease of Online booking  \
# ...

# %%
gender = data["Gender"].to_list()
customer_type = data["Customer Type"].to_list()
age = data["Age"].to_list()
type_of_travel = data["Type of Travel"].to_list()
Class = data["Class"].to_list()
flight_distance = data["Flight Distance"].to_list()
inflight_wifi_service = data["Inflight wifi service"].to_list()
departure_arrival_time_convenient = data["Departure/Arrival time convenient"].to_list()
ease_of_online_booking = data["Ease of Online booking"].to_list()
gate_location = data["Gate location"].to_list()
food_and_drink = data["Food and drink"].to_list()
online_boarding = data["Online boarding"].to_list()
seat_comfort = data["Seat comfort"].to_list()
inflight_entertainment = data["Inflight entertainment"].to_list()
on_board_service = data["On-board service"].to_list()
leg_room_service = data["Leg room service"].to_list()
baggage_handling = data["Baggage handling"].to_list()
checkin_service = data["Checkin service"].to_list()
inflight_service = data["Inflight service"].to_list()
cleanliness = data["Cleanliness"].to_list()
departure_delay_in_minutes = data["Departure Delay in Minutes"].to_list()
satisfaction = data["satisfaction"].to_list()

# %%
dic = {
    col[0]:gender,
    col[1]:customer_type,
    col[2]:age,
    col[3]:type_of_travel,
    col[4]:Class,
    col[5]:flight_distance,
    col[6]:inflight_wifi_service,
    col[7]:departure_arrival_time_convenient,
    col[8]:ease_of_online_booking,
    col[9]:gate_location,
    col[10]:food_and_drink,
    col[11]:online_boarding,
    col[12]:seat_comfort,
    col[13]:inflight_entertainment,
    col[14]:on_board_service,
    col[15]:leg_room_service,
    col[16]:baggage_handling,
    col[17]:checkin_service,
    col[18]:inflight_service,
    col[19]:cleanliness,
    col[20]:departure_delay_in_minutes,
    col[21]:satisfaction
}

# %%
dic
# Out:
# {'Gender': ['Male',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Female',
#   'Male',
#   'Female',
#   'Male',
#   'Male',
#   'Female',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Male',
#   'Male',
#   'Female',
#   'Female',
#   'Male',
#   'Male',
#   'Male',
#   'Male',
# ...

# %%
data.to_csv('/Users/irenewalken/Documents/GitHub/Airline-Passenger-Satisfaction-Machine_learning-/Data_for_tableau.csv')
